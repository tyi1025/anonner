# %%
import nltk
from nltk.corpus import conll2002
from nltk.corpus.reader import ConllCorpusReader
from nltk.corpus.reader import ChunkedCorpusReader
import nltk.chunk.named_entity
from nltk.classify import MaxentClassifier
import pickle

nltk.config_megam('../megam_i686.opt')

# %%
def preprocessingConll2003(filename, new_filename):
    with open(filename) as f:
        lines = f.readlines()
    filtered_lines = [line for line in lines if ("docstart" not in line.lower())]
    with open(new_filename, "w") as f:
        f.writelines(filtered_lines)
preprocessingConll2003('../conll2003eng/eng.train', '../conll2003eng/eng.train.preprocessed')

# %%
# test = ConllCorpusReader('CoNLL-2003', 'deu.testa', ['words', 'pos', 'ignore', 'chunk'])
# training = open(os.path.join('../conll2003eng', 'eng.train'), 'r')
# for line in training:
#     if not line:
#         continue
# training.close()


train = ConllCorpusReader('../conll2003eng', 'eng.train.preprocessed', ['words',  'pos', 'ignore', 'chunk'])
# for tree in train.chunked_sents():
#     if

# print(train.chunked_sents())
# print()

ne_chunker = nltk.chunk.named_entity.NEChunkParser(train.chunked_sents())
filename = '../models/conll2003eng'
pickle.dump(ne_chunker, open(filename, 'wb'))

# %%
test = ConllCorpusReader('../conll2003eng', 'eng.testa', ['words',  'pos', 'ignore', 'chunk'])
test_sents = test.chunked_sents()

loaded = pickle.load(open('../models/conll2003eng', 'rb'))
print(loaded.evaluate(test_sents))
# Out:
# ChunkParse score:
#     IOB Accuracy:  95.5%%
#     Precision:     77.3%%
#     Recall:        76.4%%
#     F-Measure:     76.9%%

# %%
train = ConllCorpusReader('../conll2003eng', 'eng.train', ['words',  'pos', 'ignore', 'chunk'])
chunks = train.chunked_sents()
print(chunks[1])
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/nltk/collections.py in __getitem__(self, index)
#     465             try:
# --> 466                 val = next(self.iterate_from(index))
#     467             except StopIteration as e:
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-c63751905129> in <module>
#       1 train = ConllCorpusReader('../conll2003eng', 'eng.train', ['words',  'pos', 'ignore', 'chunk'])
#       2 chunks = train.chunked_sents()
# ----> 3 print(chunks[1])
#
# ~/.local/lib/python3.5/site-packages/nltk/collections.py in __getitem__(self, index)
#     466                 val = next(self.iterate_from(index))
#     467             except StopIteration as e:
# ...

# %%
a = conll2002.chunked_sents('ned.train')
print(a[3])
# Out:
# (S
#   Vandaag/Adv
#   is/V
#   (ORG Floralux/N)
#   dus/Adv
#   met/Prep
#   alle/Pron
#   vergunningen/N
#   in/Prep
#   orde/N
#   ,/Punc
#   maar/Conj
#   het/Art
#   (MISC BPA/N)
#   waarmee/Adv
#   die/Pron
#   konden/V
#   verkregen/V
#   worden/V
#   ,/Punc
#   was/V
#   omstreden/Adj
#   omdat/Conj
#   zaakvoerster/N
#   (PER Christiane/N Vandenbussche/N)
#   haar/Pron
#   schepenambt/N
#   van/Prep
#   .../Punc)

# %%
            ("words", "pos", "chunk"),# test = ConllCorpusReader('CoNLL-2003', 'deu.testa', ['words', 'pos', 'ignore', 'chunk'])
ne_chunker = nltk.chunk.named_entity.NEChunkParser(train.chunked_sents())
filename = 'model1'
pickle.dump(ne_chunker, open(filename, 'wb'))

# %%
psource conll2002

# %%
ConllCorpusReader(
    # root = FileSystemPathPointer('/home/conll2003deu'),
    root = '/home/wangt/conll2003ger',
    fileids = r"..(test|train).",
    columntypes=['words', 'pos', 'ignore', 'chunk'],
    chunk_types=('LOC', 'PER', 'ORG', 'MISC'),
)
# Out:
# <ConllCorpusReader in '/home/wangt/conll2003ger'>

# %%
ls
# Out:
# conll2003eng/  GER03B05.ECI     megam_i686.opt*  nltk_data/
# conll2003ger/  megamDemo.ipynb  ner.tgz          thesis_code/

# %%
psource ConllChunkCorpusReader
# Out:
# Object `ConllChunkCorpusReader` not found.

# %%
psource ConllCorpusReader
# Out:
# class ConllCorpusReader(CorpusReader):
#     """
#     A corpus reader for CoNLL-style files.  These files consist of a
#     series of sentences, separated by blank lines.  Each sentence is
#     encoded using a table (or "grid") of values, where each line
#     corresponds to a single word, and each column corresponds to an
#     annotation type.  The set of columns used by CoNLL-style files can
#     vary from corpus to corpus; the ``ConllCorpusReader`` constructor
#     therefore takes an argument, ``columntypes``, which is used to
#     specify the columns that are used by a given corpus. By default
#     columns are split by consecutive whitespaces, with the
#     ``separator`` argument you can set a string to split by (e.g.
#     ``\'\t\'``).
#
#
#     @todo: Add support for reading from corpora where different
#         parallel files contain different columns.
#     @todo: Possibly add caching of the grid corpus view?  This would
# ...
